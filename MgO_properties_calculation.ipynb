# %%
#!/bin/bash
## Number of slots to use for the calculation---MUST be less or equal to 2
NSLOTS=1
## Uncomment the desired line
#cp MgO_DOSS.d3 MgO.d3 # for DOSS calculation
#cp MgO_BAND.d3 MgO.d3 # for BAND STRUCTURE calculation
cp MgO_ECHG.d3 MgO.d3 # for ELECTRON DENSITY MAPS calculation
## FILEPREFIX
FILEPREFIX=MgO
## Name of .d12 file without its .d12 extension
FICD12=$FILEPREFIX
## F9PREFIX
F9PREFIX=$FICD12/$FILEPREFIX
## Execution
runmpi_prop17 "$NSLOTS" "$FICD12" "$FILEPREFIX" "$F9PREFIX"
cat $FILEPREFIX/"$FILEPREFIX".prop
# Out:
# output data in /home/jupyter/Notebooks/TP_DFT_Master/MgO/MgO.prop
# creating temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p24657_jupyter
# scf guess from /home/jupyter/Notebooks/TP_DFT_Master/MgO/MgO.f9
# rm: No match.
# properties input data in /home/jupyter/Notebooks/TP_DFT_Master/MgO.d3
# copying input file
# file fort.13 saved as /home/jupyter/Notebooks/TP_DFT_Master/MgO/MgO.f13
# file fort.25 saved as /home/jupyter/Notebooks/TP_DFT_Master/MgO/MgO.f25
# removing temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p24657_jupyter
# date Sun Jan 27 17:22:54 UTC 2019
# user jupyter
# output data in /home/jupyter/Notebooks/TP_DFT_Master/MgO/MgO.prop
# creating temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p24657_jupyter
# scf guess from /home/jupyter/Notebooks/TP_DFT_Master/MgO/MgO.f9
# properties input data in /home/jupyter/Notebooks/TP_DFT_Master/MgO.d3
# ECHG
# 0
# 65
# COORDINA
# -4. -4. 0.0
# 4. -4. 0.0
# 4. 4. 0.0
# MARGINS
# 1.5 1.5 1.5 1.5
# END
# PATO
# 0 0
# ECHG
# 0
# 65
# COORDINA
# -4. -4. 0.0
# 4. -4. 0.0
# 4. 4. 0.0
# MARGINS
# 1.5 1.5 1.5 1.5
# END
# ENDcopying input file
# properties job running in /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p24657_jupyter ...
#
#
#  *******************************************************************************
#  *                                                                             *
#  *                               CRYSTAL17                                     *
#  *                      public : 1.0.1 - Jun 21st, 2017                        *
#  *                       HTTP://WWW.CRYSTAL.UNITO.IT                           *
#  *                                                                             *
#  *                              MAIN AUTHORS                                   *
#  *                                                                             *
#  *  R. DOVESI(1,11), V.R. SAUNDERS(2), C. ROETTI(1,11), R. ORLANDO(1,11),      *
#  *  C.M. ZICOVICH-WILSON(1,3), F. PASCALE(4), B. CIVALLERI(1,11),              *
#  *  K. DOLL(5), N.M. HARRISON(2,6), I.J. BUSH(7), Ph. D'ARCO(8),               *
#  *  M. LLUNELL(9), M. CAUSA'(10), Y. NOEL(8), L. MASCHIO(1,11), A. ERBA(1,11)  *
#  *  M. RE'RAT(14), S. CASASSA(1,11)                                            *
#  *                                                                             *
#  *        CONTRIBUTIONS TO THE CODE HAVE ALSO BEEN GIVEN BY                    *
#  *                                                                             *
#  *  M. FERRABONE(1,11), M. DE LA PIERRE(1,11), M. FERRERO(1,11),               *
#  *  J. BAIMA(1,11), E. ALBANESE(1,11), M.F. PEINTINGER(12), R. BAST(13),       *
#  *  B. KIRTMAN(15), V. LACIVITA(1,11), R. DEMICHELIS(1,16)                     *
#  *  G. BRANDEBURG(17), S. SALUSTRO(1,11), G. SANSONE(1,11)                     *
#  *  M.T. RUGGIERO(18)                                                          *
#  *                                                                             *
#  * (1) THEORETICAL CHEMISTRY GROUP - UNIVERSITA' DI TORINO - TORINO (ITALY)    *
#
#  * (2) COMPUTATIONAL SCIENCE & ENGINEERING DEPARTMENT - STFC DARESBURY (UK)    *
#  * (3) UNIVERSIDAD AUTONOMA DEL ESTADO DE MORELOS - CUERNAVACA (MEXICO)        *
#  * (4) UNIVERSITE' DE LORRAINE - NANCY (FRANCE)                                *
#  * (5) UNIVERSITAET STUTTGART- STUTTGART (GERMANY)                             *
#  * (6) IMPERIAL COLLEGE - LONDON (UK)                                          *
#  * (7) OXFORD E-RESEARCH CENTRE - OXFORD (UK)                                  *
#  * (8) UPMC - SORBONNE UNIVERSITES - PARIS (FRANCE)                            *
#  * (9) UNIVERSIDAD DE BARCELONA - BARCELONA (SPAIN)                            *
#  *(10) UNIVERSITA' DI NAPOLI "FEDERICO II" - NAPOLI (ITALY)                    *
#  *(11) NIS - NANOSTRUCTURED INTERFACES AND SURFACES - TORINO (ITALY)           *
#  *(12) MPI FUER CHEMISCHE ENERGIEKONVERSION - MUELHEIM AN DER RUHR (GERMANY)   *
#  *(13) UNIVERSITY OF TROMSO - TROMSO (NORWAY)                                  *
#  *(14) UNIVERSITE' DE PAU ET DES PAYS DE L'ADOUR - PAU (FRANCE)                *
#  *(15) UNIVERSITY OF CALIFORNIA SANTA BARBARA - SANTA BARBARA (USA)            *
#  *(16) CURTIN UNIVERSITY - PERTH (AUSTRALIA)                                   *
#  *(17) UNIVERSITY COLLEGE LONDON - LONDON (UK)                                 *
#  *(18) CAMBRIDGE UNIVERSITY - CAMBRIDGE (UK)                                   *
#  *                                                                             *
#  *******************************************************************************
#  EEEEEEEEEE STARTING  DATE 27 01 2019 TIME 17:22:54.3
#
#  *******************************************************************************
#  MGO BULK - 85-11G BASIS SET FOR MG AND 84-11G FOR O
#  CRYSTAL - PROPERTIES - TYPE OF CALCULATION :  RESTRICTED CLOSED SHELL
#  *******************************************************************************
#  KOHN-SHAM HAMILTONIAN
#
#  (EXCHANGE)[CORRELATION] FUNCTIONAL:(PERDEW-BURKE-ERNZERHOF)[PERDEW-BURKE-ERNZERHOF]
#
#
#  HYBRID EXCHANGE - PERCENTAGE OF FOCK EXCHANGE    25.0000
#
#  DIRECT LATTICE VECTOR COMPONENTS (ANGSTROM)
#          0.00000    2.10650    2.10650
#          2.10650    0.00000    2.10650
#          2.10650    2.10650    0.00000
#
#  LATTICE PARAMETERS  (ANGSTROM AND DEGREES) - PRIMITIVE CELL
#        A          B          C         ALPHA      BETA     GAMMA        VOLUME
#     2.97904    2.97904    2.97904     60.0000   60.0000   60.0000      18.69452
#  *******************************************************************************
#  N. OF ATOMS PER CELL         2 COULOMB OVERLAP TOL          (T1) 10**   -6
#  NUMBER OF SHELLS             8 COULOMB PENETRATION TOL      (T2) 10**   -6
#  NUMBER OF AO                26 EXCHANGE OVERLAP TOL         (T3) 10**   -6
#  N. OF ELECTRONS PER CELL    20 EXCHANGE PSEUDO OVP (F(G))   (T4) 10**   -6
#  CORE ELECTRONS PER CELL     12 EXCHANGE PSEUDO OVP (P(G))   (T5) 10**  -12
#  N. OF SYMMETRY OPERATORS    48 POLE ORDER IN MONO ZONE                   4
#  *******************************************************************************
#    ATOM N.AT.  SHELL    X(A)      Y(A)      Z(A)      EXAD       N.ELECT.
#  *******************************************************************************
#     1   12 MG    4     0.000     0.000     0.000   2.800E-01      10.121
#     2    8 O     4     2.107     2.107     2.107   1.910E-01       9.879
#  *******************************************************************************
#  DE(K)                   0.000E+00  ENERGY LEVEL SHIFTING        0.00000
#  TOTAL ENERGY -2.7532622743366E+02  CONVERGENCE ON ENER        5.006E-09
#  KIN. ENERGY   2.7428461269797E+02  VIR. COEFF.           1.03387243E+00
#  N. OF SCF CYCLES                6  FERMI ENERGY              -0.176E+00
#  WEIGHT OF F(I) IN F(I+1)      30
#  SHRINK. FACT.(MONKH.)     8  8  8  SHRINKING FACTOR(GILAT NET)        8
#  NUMBER OF K POINTS IN THE IBZ  29  CELL VOLUME (A.U.)        126.156896
#  *******************************************************************************
#
#  GCALCO - MAX INDICES DIRECT LATTICE VECTOR    14    14    14
#  NO.OF VECTORS CREATED 6999 STARS  105 RMAX    59.57778 BOHR
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT gordsh1     TELAPSE        0.01 TCPU        0.01
#
#  MATRIX SIZE: P(G)   31930, F(G)    5766, P(G) IRR    1564, F(G) IRR     822
#  MAX G-VECTOR INDEX FOR 1- AND 2-ELECTRON INTEGRALS 319
#
#
#  CAPPA:IS1  8;IS2  8;IS3  8; K PTS MONK NET  29; SYMMOPS:K SPACE  48;G SPACE  48
#
#  CHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCH
#
#  ELECTRON CHARGE (AND SPIN) DENSITY - DERIVATIVES UP TO ORDER 0
#
#  CHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCH
#
#  CO-ORDINATES IN ANGSTROM
#  REDEFINITION OF THE WINDOW AS A RECTANGULAR WINDOW
#  MARGINS (BOHR):   2.8346   2.8346 ALONG B-C,   2.8346   2.8346 ALONG A-B
#
#                         COORDINATES OF THE 3 POINTS (BOHR):
#               A)  -10.393  -10.393    0.000 POINT INDICES (  1,  1)
#               B)   10.393  -10.393    0.000 POINT INDICES (NPY,  1)
#               C)   10.393   10.393    0.000 POINT INDICES (NPY,NPX)
#
#  N. OF POINTS ALONG THE A-B SEGMENT (NPY)   65
#  N. OF POINTS ALONG THE B-C SEGMENT (NPX)   65
#  N. OF POINTS IN THE GRID :               4225
#  COSINE OF THE ANGLE A-B-C              0.0000
#  N. OF ELEMENTS IN THE SYMMETRY SUB-GROUP   16
#  N. OF POINTS IN THE IRREDUCIBLE ZONE :   2145
#
#
#     ALPHA+BETA ELECTRONS DENSITY - VALMIN  1.6725E-02 VALMAX  1.0622E+03
#
#  4225 DATA WRITTEN ON UNIT 25 WITH THE FOLLOWING HEADER
# -%-0MAPN   65   65 0.32480E+00 0.32480E+00 0.00000E+00
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT ECHG        TELAPSE        0.32 TCPU        0.27
#
#  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#          ATOMIC WAVEFUNCTION(S)
#
#
#  NUCLEAR CHARGE 12.0  SYMMETRY SPECIES            S    P
#  N. ELECTRONS   10.0  NUMBER OF PRIMITIVE GTOS   15    7
#                       NUMBER OF CONTRACTED GTOS   4    3
#                       NUMBER OF CLOSED SHELLS     2    1
#                       OPEN SHELL OCCUPATION       0    0
#
#   ZNUC SCFIT  TOTAL HF ENERGY   KINETIC ENERGY   VIRIAL THEOREM ACCURACY
#   12.0   8   -1.988221335E+02  1.987531251E+02 -2.000347207E+00  3.4E-06
#
#  NUCLEAR CHARGE  8.0  SYMMETRY SPECIES            S    P
#  N. ELECTRONS   10.0  NUMBER OF PRIMITIVE GTOS   14    6
#                       NUMBER OF CONTRACTED GTOS   4    3
#                       NUMBER OF CLOSED SHELLS     2    1
#                       OPEN SHELL OCCUPATION       0    0
#
#   ZNUC SCFIT  TOTAL HF ENERGY   KINETIC ENERGY   VIRIAL THEOREM ACCURACY
#    8.0  61   -7.433102083E+01  7.469307318E+01 -1.995152799E+00  4.6E-06
#
#  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#
#
#  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#          ATOMIC WAVEFUNCTION(S)
#
#
#  NUCLEAR CHARGE 12.0  SYMMETRY SPECIES            S    P
#  N. ELECTRONS   10.0  NUMBER OF PRIMITIVE GTOS   15    7
#                       NUMBER OF CONTRACTED GTOS   4    3
#                       NUMBER OF CLOSED SHELLS     2    1
#                       OPEN SHELL OCCUPATION       0    0
#
#   ZNUC SCFIT  TOTAL HF ENERGY   KINETIC ENERGY   VIRIAL THEOREM ACCURACY
#   12.0   8   -1.988221335E+02  1.987531251E+02 -2.000347207E+00  3.4E-06
#
#  NUCLEAR CHARGE  8.0  SYMMETRY SPECIES            S    P
#  N. ELECTRONS   10.0  NUMBER OF PRIMITIVE GTOS   14    6
#                       NUMBER OF CONTRACTED GTOS   4    3
#                       NUMBER OF CLOSED SHELLS     2    1
#                       OPEN SHELL OCCUPATION       0    0
#
#   ZNUC SCFIT  TOTAL HF ENERGY   KINETIC ENERGY   VIRIAL THEOREM ACCURACY
#    8.0  61   -7.433102083E+01  7.469307318E+01 -1.995152799E+00  4.6E-06
#
#  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#
#  *******************************************************************************
#  DENSITY MATRIX AS SUPERPOSITION OF ATOMIC DENSITIES
#  *******************************************************************************
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT PATO        TELAPSE        0.53 TCPU        0.28
#  CHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCH
#
#  ELECTRON CHARGE (AND SPIN) DENSITY - DERIVATIVES UP TO ORDER 0
#
#  CHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCH
#
#  CO-ORDINATES IN ANGSTROM
#  REDEFINITION OF THE WINDOW AS A RECTANGULAR WINDOW
#  MARGINS (BOHR):   2.8346   2.8346 ALONG B-C,   2.8346   2.8346 ALONG A-B
#
#                         COORDINATES OF THE 3 POINTS (BOHR):
#               A)  -10.393  -10.393    0.000 POINT INDICES (  1,  1)
#               B)   10.393  -10.393    0.000 POINT INDICES (NPY,  1)
#               C)   10.393   10.393    0.000 POINT INDICES (NPY,NPX)
#
#  N. OF POINTS ALONG THE A-B SEGMENT (NPY)   65
#  N. OF POINTS ALONG THE B-C SEGMENT (NPX)   65
#  N. OF POINTS IN THE GRID :               4225
#  COSINE OF THE ANGLE A-B-C              0.0000
#  N. OF ELEMENTS IN THE SYMMETRY SUB-GROUP   16
#  N. OF POINTS IN THE IRREDUCIBLE ZONE :   2145
#
#
#     ALPHA+BETA ELECTRONS DENSITY - VALMIN  1.8606E-02 VALMAX  1.0625E+03
#
#  4225 DATA WRITTEN ON UNIT 25 WITH THE FOLLOWING HEADER
# -%-0MAPN   65   65 0.32480E+00 0.32480E+00 0.00000E+00
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT ECHG        TELAPSE        0.81 TCPU        0.56
#  ENDPROP
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT END         TELAPSE        0.81 TCPU        0.56
#  EEEEEEEEEE TERMINATION  DATE 27 01 2019 TIME 17:22:55.1
# Sun Jan 27 17:22:55 UTC 2019
# Contents of temporary directory in master node temporaryHostname:
# total 1072
# -rw-rw-r--. 1 jupyter jupyter  46136 Jan 27 17:22 fort.11
# -rw-rw-r--. 1 jupyter jupyter 766344 Jan 27 17:22 fort.13
# -rw-rw-r--. 1 jupyter jupyter 103802 Jan 27 17:22 fort.25
# -rw-rw-r--. 1 jupyter jupyter  46136 Jan 27 17:22 fort.3
# -rw-rw-r--. 1 jupyter jupyter 122372 Jan 27 17:22 fort.9
# lrwxrwxrwx. 1 jupyter jupyter     44 Jan 27 17:22 INPUT -> /home/jupyter/Notebooks/TP_DFT_Master/MgO.d3
# file fort.13 saved as /home/jupyter/Notebooks/TP_DFT_Master/MgO/MgO.f13
# file fort.25 saved as /home/jupyter/Notebooks/TP_DFT_Master/MgO/MgO.f25
# removing temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p24657_jupyter
