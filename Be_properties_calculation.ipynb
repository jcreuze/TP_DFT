# %%
#!/bin/bash
## Number of slots to use for the calculation---MUST be less or equal to 2
NSLOTS=1
## Uncomment the desired line
#cp Be_DOSS.d3 Be.d3 # for DOSS calculation
#cp Be_BAND.d3 Be.d3 # for BAND STRUCTURE calculation
cp Be_ECHG.d3 Be.d3 # for ELECTRON DENSITY MAPS calculation
## FILEPREFIX
FILEPREFIX=Be
## Name of .d12 file without its .d12 extension
FICD12=$FILEPREFIX
## F9PREFIX
F9PREFIX=$FICD12/$FILEPREFIX
## Execution
runmpi_prop17 "$NSLOTS" "$FICD12" "$FILEPREFIX" "$F9PREFIX"
cat $FILEPREFIX/"$FILEPREFIX".prop
# Out:
# output data in /home/jupyter/Notebooks/TP_DFT_Master/Be/Be.prop
# creating temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p23906_jupyter
# scf guess from /home/jupyter/Notebooks/TP_DFT_Master/Be/Be.f9
# rm: No match.
# properties input data in /home/jupyter/Notebooks/TP_DFT_Master/Be.d3
# copying input file
# file fort.13 saved as /home/jupyter/Notebooks/TP_DFT_Master/Be/Be.f13
# file fort.25 saved as /home/jupyter/Notebooks/TP_DFT_Master/Be/Be.f25
# removing temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p23906_jupyter
# date Sun Jan 27 16:00:49 UTC 2019
# user jupyter
# output data in /home/jupyter/Notebooks/TP_DFT_Master/Be/Be.prop
# creating temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p23906_jupyter
# scf guess from /home/jupyter/Notebooks/TP_DFT_Master/Be/Be.f9
# properties input data in /home/jupyter/Notebooks/TP_DFT_Master/Be.d3
# ECHG
# 0
# 95
# COORDINA
# -2.498 0.000 1.696
# -2.498 0.000 -1.696
# -1.249 -2.164 -1.696
# RECTANGU
# MARGINS
# 3. 3. 3. 3.
# END
# PATO
# 0 0
# ECHG
# 0
# 95
# COORDINA
# -2.498 0.000 1.696
# -2.498 0.000 -1.696
# -1.249 -2.164 -1.696
# RECTANGU
# MARGINS
# 3. 3. 3. 3.
# END
# ENDcopying input file
# properties job running in /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p23906_jupyter ...
#
#
#  *******************************************************************************
#  *                                                                             *
#  *                               CRYSTAL17                                     *
#  *                      public : 1.0.1 - Jun 21st, 2017                        *
#  *                       HTTP://WWW.CRYSTAL.UNITO.IT                           *
#  *                                                                             *
#  *                              MAIN AUTHORS                                   *
#  *                                                                             *
#  *  R. DOVESI(1,11), V.R. SAUNDERS(2), C. ROETTI(1,11), R. ORLANDO(1,11),      *
#  *  C.M. ZICOVICH-WILSON(1,3), F. PASCALE(4), B. CIVALLERI(1,11),              *
#  *  K. DOLL(5), N.M. HARRISON(2,6), I.J. BUSH(7), Ph. D'ARCO(8),               *
#  *  M. LLUNELL(9), M. CAUSA'(10), Y. NOEL(8), L. MASCHIO(1,11), A. ERBA(1,11)  *
#  *  M. RE'RAT(14), S. CASASSA(1,11)                                            *
#  *                                                                             *
#  *        CONTRIBUTIONS TO THE CODE HAVE ALSO BEEN GIVEN BY                    *
#  *                                                                             *
#  *  M. FERRABONE(1,11), M. DE LA PIERRE(1,11), M. FERRERO(1,11),               *
#  *  J. BAIMA(1,11), E. ALBANESE(1,11), M.F. PEINTINGER(12), R. BAST(13),       *
#  *  B. KIRTMAN(15), V. LACIVITA(1,11), R. DEMICHELIS(1,16)                     *
#  *  G. BRANDEBURG(17), S. SALUSTRO(1,11), G. SANSONE(1,11)                     *
#  *  M.T. RUGGIERO(18)                                                          *
#  *                                                                             *
#  * (1) THEORETICAL CHEMISTRY GROUP - UNIVERSITA' DI TORINO - TORINO (ITALY)    *
#
#  * (2) COMPUTATIONAL SCIENCE & ENGINEERING DEPARTMENT - STFC DARESBURY (UK)    *
#  * (3) UNIVERSIDAD AUTONOMA DEL ESTADO DE MORELOS - CUERNAVACA (MEXICO)        *
#  * (4) UNIVERSITE' DE LORRAINE - NANCY (FRANCE)                                *
#  * (5) UNIVERSITAET STUTTGART- STUTTGART (GERMANY)                             *
#  * (6) IMPERIAL COLLEGE - LONDON (UK)                                          *
#  * (7) OXFORD E-RESEARCH CENTRE - OXFORD (UK)                                  *
#  * (8) UPMC - SORBONNE UNIVERSITES - PARIS (FRANCE)                            *
#  * (9) UNIVERSIDAD DE BARCELONA - BARCELONA (SPAIN)                            *
#  *(10) UNIVERSITA' DI NAPOLI "FEDERICO II" - NAPOLI (ITALY)                    *
#  *(11) NIS - NANOSTRUCTURED INTERFACES AND SURFACES - TORINO (ITALY)           *
#  *(12) MPI FUER CHEMISCHE ENERGIEKONVERSION - MUELHEIM AN DER RUHR (GERMANY)   *
#  *(13) UNIVERSITY OF TROMSO - TROMSO (NORWAY)                                  *
#  *(14) UNIVERSITE' DE PAU ET DES PAYS DE L'ADOUR - PAU (FRANCE)                *
#  *(15) UNIVERSITY OF CALIFORNIA SANTA BARBARA - SANTA BARBARA (USA)            *
#  *(16) CURTIN UNIVERSITY - PERTH (AUSTRALIA)                                   *
#  *(17) UNIVERSITY COLLEGE LONDON - LONDON (UK)                                 *
#  *(18) CAMBRIDGE UNIVERSITY - CAMBRIDGE (UK)                                   *
#  *                                                                             *
#  *******************************************************************************
#  EEEEEEEEEE STARTING  DATE 27 01 2019 TIME 16:00:49.6
#
#  *******************************************************************************
#  BERILLIUM BULK
#  CRYSTAL - PROPERTIES - TYPE OF CALCULATION :  RESTRICTED CLOSED SHELL
#  *******************************************************************************
#  HARTREE-FOCK HAMILTONIAN
#
#  DIRECT LATTICE VECTOR COMPONENTS (ANGSTROM)
#          1.98320   -1.14500    0.00000
#          0.00000    2.29000    0.00000
#          0.00000    0.00000    3.59000
#
#  LATTICE PARAMETERS  (ANGSTROM AND DEGREES) - PRIMITIVE CELL
#        A          B          C         ALPHA      BETA     GAMMA        VOLUME
#     2.29000    2.29000    3.59000     90.0000   90.0000  120.0000      16.30407
#  *******************************************************************************
#  N. OF ATOMS PER CELL         2 COULOMB OVERLAP TOL          (T1) 10**   -6
#  NUMBER OF SHELLS             8 COULOMB PENETRATION TOL      (T2) 10**   -6
#  NUMBER OF AO                20 EXCHANGE OVERLAP TOL         (T3) 10**   -6
#  N. OF ELECTRONS PER CELL     8 EXCHANGE PSEUDO OVP (F(G))   (T4) 10**   -6
#  CORE ELECTRONS PER CELL      4 EXCHANGE PSEUDO OVP (P(G))   (T5) 10**  -12
#  N. OF SYMMETRY OPERATORS    24 POLE ORDER IN MONO ZONE                   4
#  *******************************************************************************
#    ATOM N.AT.  SHELL    X(A)      Y(A)      Z(A)      EXAD       N.ELECT.
#  *******************************************************************************
#     1    4 BE    4    -1.322     0.000     0.897   2.700E-01       4.000
#     2    4 BE    4    -0.661    -1.145    -0.897   2.700E-01       4.000
#  *******************************************************************************
#  DE(K)                   0.000E+00  ENERGY LEVEL SHIFTING        0.00000
#  TOTAL ENERGY -2.9246234715497E+01  CONVERGENCE ON ENER       -2.960E-07
#  KIN. ENERGY   2.9282126230013E+01  VIR. COEFF.           1.00061323E+00
#  N. OF SCF CYCLES                8  FERMI ENERGY              -0.782E-01
#  WEIGHT OF F(I) IN F(I+1)      30
#  SHRINK. FACT.(MONKH.)    12 12 12  SHRINKING FACTOR(GILAT NET)       24
#  NUMBER OF K POINTS IN THE IBZ 133  CELL VOLUME (A.U.)        110.025323
#  *******************************************************************************
#
#  GCALCO - MAX INDICES DIRECT LATTICE VECTOR    18    18     9
#  NO.OF VECTORS CREATED 6999 STARS  372 RMAX    56.80741 BOHR
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT gordsh1     TELAPSE        0.01 TCPU        0.01
#
#  MATRIX SIZE: P(G)   20468, F(G)    3798, P(G) IRR    1072, F(G) IRR     459
#  MAX G-VECTOR INDEX FOR 1- AND 2-ELECTRON INTEGRALS 233
#
#
#  CAPPA:IS1 12;IS2 12;IS3 12; K PTS MONK NET 133; SYMMOPS:K SPACE  24;G SPACE  24
#
#  CHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCH
#
#  ELECTRON CHARGE (AND SPIN) DENSITY - DERIVATIVES UP TO ORDER 0
#
#  CHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCH
#
#  CO-ORDINATES IN ANGSTROM
#  REDEFINITION OF THE WINDOW AS A RECTANGULAR WINDOW
#  MARGINS (BOHR):   5.6692   5.6692 ALONG B-C,   5.6692   5.6692 ALONG A-B
#
#                         COORDINATES OF THE 3 POINTS (BOHR):
#               A)   -7.554    4.910    8.874 POINT INDICES (  1,  1)
#               B)   -7.554    4.910   -8.874 POINT INDICES (NPY,  1)
#               C)    0.474   -8.999   -8.874 POINT INDICES (NPY,NPX)
#
#  N. OF POINTS ALONG THE A-B SEGMENT (NPY)   95
#  N. OF POINTS ALONG THE B-C SEGMENT (NPX)   86
#  N. OF POINTS IN THE GRID :               8170
#  COSINE OF THE ANGLE A-B-C              0.0000
#  N. OF ELEMENTS IN THE SYMMETRY SUB-GROUP    4
#  N. OF POINTS IN THE IRREDUCIBLE ZONE :   8170
#
#
#     ALPHA+BETA ELECTRONS DENSITY - VALMIN  2.1876E-02 VALMAX  5.5225E+00
#
#  8170 DATA WRITTEN ON UNIT 25 WITH THE FOLLOWING HEADER
# -%-2MAPN   95   86 0.18881E+00 0.18894E+00 0.00000E+00
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT ECHG        TELAPSE        0.51 TCPU        0.49
#
#  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#          ATOMIC WAVEFUNCTION(S)
#
#
#  NUCLEAR CHARGE  4.0  SYMMETRY SPECIES            S
#  N. ELECTRONS    4.0  NUMBER OF PRIMITIVE GTOS    8
#                       NUMBER OF CONTRACTED GTOS   4
#                       NUMBER OF CLOSED SHELLS     2
#                       OPEN SHELL OCCUPATION       0
#
#   ZNUC SCFIT  TOTAL HF ENERGY   KINETIC ENERGY   VIRIAL THEOREM ACCURACY
#    4.0   6   -1.432538044E+01  1.554397278E+01 -1.921603546E+00  8.1E-07
#
#  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#
#
#  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#          ATOMIC WAVEFUNCTION(S)
#
#
#  NUCLEAR CHARGE  4.0  SYMMETRY SPECIES            S
#  N. ELECTRONS    4.0  NUMBER OF PRIMITIVE GTOS    8
#                       NUMBER OF CONTRACTED GTOS   4
#                       NUMBER OF CLOSED SHELLS     2
#                       OPEN SHELL OCCUPATION       0
#
#   ZNUC SCFIT  TOTAL HF ENERGY   KINETIC ENERGY   VIRIAL THEOREM ACCURACY
#    4.0   6   -1.432538044E+01  1.554397278E+01 -1.921603546E+00  8.1E-07
#
#  AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
#
#  *******************************************************************************
#  DENSITY MATRIX AS SUPERPOSITION OF ATOMIC DENSITIES
#  *******************************************************************************
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT PATO        TELAPSE        0.54 TCPU        0.49
#  CHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCH
#
#  ELECTRON CHARGE (AND SPIN) DENSITY - DERIVATIVES UP TO ORDER 0
#
#  CHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCHCH
#
#  CO-ORDINATES IN ANGSTROM
#  REDEFINITION OF THE WINDOW AS A RECTANGULAR WINDOW
#  MARGINS (BOHR):   5.6692   5.6692 ALONG B-C,   5.6692   5.6692 ALONG A-B
#
#                         COORDINATES OF THE 3 POINTS (BOHR):
#               A)   -7.554    4.910    8.874 POINT INDICES (  1,  1)
#               B)   -7.554    4.910   -8.874 POINT INDICES (NPY,  1)
#               C)    0.474   -8.999   -8.874 POINT INDICES (NPY,NPX)
#
#  N. OF POINTS ALONG THE A-B SEGMENT (NPY)   95
#  N. OF POINTS ALONG THE B-C SEGMENT (NPX)   86
#  N. OF POINTS IN THE GRID :               8170
#  COSINE OF THE ANGLE A-B-C              0.0000
#  N. OF ELEMENTS IN THE SYMMETRY SUB-GROUP    4
#  N. OF POINTS IN THE IRREDUCIBLE ZONE :   8170
#
#
#     ALPHA+BETA ELECTRONS DENSITY - VALMIN  1.2208E-02 VALMAX  5.7110E+00
#
#  8170 DATA WRITTEN ON UNIT 25 WITH THE FOLLOWING HEADER
# -%-2MAPN   95   86 0.18881E+00 0.18894E+00 0.00000E+00
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT ECHG        TELAPSE        1.01 TCPU        0.96
#  ENDPROP
#  TTTTTTTTTTTTTTTTTTTTTTTTTTTTTT END         TELAPSE        1.01 TCPU        0.96
#  EEEEEEEEEE TERMINATION  DATE 27 01 2019 TIME 16:00:50.6
# Sun Jan 27 16:00:50 UTC 2019
# Contents of temporary directory in master node temporaryHostname:
# total 848
# -rw-rw-r--. 1 jupyter jupyter  30392 Jan 27 16:00 fort.11
# -rw-rw-r--. 1 jupyter jupyter 491256 Jan 27 16:00 fort.13
# -rw-rw-r--. 1 jupyter jupyter 199796 Jan 27 16:00 fort.25
# -rw-rw-r--. 1 jupyter jupyter  30392 Jan 27 16:00 fort.3
# -rw-rw-r--. 1 jupyter jupyter 109980 Jan 27 16:00 fort.9
# lrwxrwxrwx. 1 jupyter jupyter     43 Jan 27 16:00 INPUT -> /home/jupyter/Notebooks/TP_DFT_Master/Be.d3
# file fort.13 saved as /home/jupyter/Notebooks/TP_DFT_Master/Be/Be.f13
# file fort.25 saved as /home/jupyter/Notebooks/TP_DFT_Master/Be/Be.f25
# removing temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p23906_jupyter
