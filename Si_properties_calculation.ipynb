# %%
#!/bin/bash
## Number of slots to use for the calculation---MUST be less or equal to 2
NSLOTS=1
## Uncomment the desired line
#cp Si_DOSS.d3 Si.d3 # for DOSS calculation
#cp Si_BAND.d3 Si.d3 # for BAND STRUCTURE calculation
cp Si_ECHG.d3 Si.d3 # for ELECTRON DENSITY MAPS calculation
## FILEPREFIX
FILEPREFIX=Si
## Name of .d12 file without its .d12 extension
FICD12=$FILEPREFIX
## F9PREFIX
F9PREFIX=$FICD12/$FILEPREFIX
## Execution
runmpi_prop17 "$NSLOTS" "$FICD12" "$FILEPREFIX" "$F9PREFIX"
cat $FILEPREFIX/"$FILEPREFIX".prop
# Out:
# output data in /home/jupyter/Notebooks/TP_DFT_Master/Si/Si.prop
# creating temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p24814_jupyter
# scf guess from /home/jupyter/Notebooks/TP_DFT_Master/Si/Si.f9
# rm: No match.
# properties input data in /home/jupyter/Notebooks/TP_DFT_Master/Si.d3
# copying input file
# file fort.13 saved as /home/jupyter/Notebooks/TP_DFT_Master/Si/Si.f13
# file fort.25 saved as /home/jupyter/Notebooks/TP_DFT_Master/Si/Si.f25
# removing temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p24814_jupyter
# date Sun Jan 27 17:41:19 UTC 2019
# user jupyter
# output data in /home/jupyter/Notebooks/TP_DFT_Master/Si/Si.prop
# creating temporary directories /home/jupyter/CRYSTAL_TEMP_DIR/tmp_p24814_jupyter
# scf guess from /home/jupyter/Notebooks/TP_DFT_Master/Si/Si.f9
# properties input data in /home/jupyter/Notebooks/TP_DFT_Master/Si.d3
# ECHG
# 0
# 65
# ATOMS
# 1 1 1 -1
# 1 0 0 0
# 1 0 0 2
# MARGINS
# 2. 2. 2. 2.
# END
# PATO
# 0 0
# ECHG
# 0
# 65
# ...
